# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# 데이터 출처
# https://www.kaggle.com/datasets/alfredkondoro/seoul-historical-weather-data-2024
from CSVImporter import import_csv

weather_df = import_csv()
weather_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1095 entries, 0 to 1094
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   year              1095 non-null   int64
#  1   month             1095 non-null   int64
#  2   day               1095 non-null   int64
#  3   temp              1095 non-null   float64
#  4   humidity          1095 non-null   float64
#  5   cloudy            1095 non-null   int64
#  6   precip            1095 non-null   float64
#  7   snow              1095 non-null   float64
#  8   windspeed         1095 non-null   float64
#  9   winddir           1095 non-null   float64
#  10  sealevelpressure  1095 non-null   float64
#  11  visibility        1095 non-null   float64
#  12  solarradiation    1095 non-null   float64
# dtypes: float64(9), int64(4)
# memory usage: 111.3 KB

# %%
weather_df['year'].value_counts()
# Out:
# year
# 2017    365
# 2018    365
# 2019    365
# Name: count, dtype: int64

# %%
# weather_df[
#     (weather_df['year'] == 2018) &
#     (weather_df['month'] == 1) &
#     (weather_df['day'] == 1)
# ]

# %%
# weather_df = weather_df.drop_duplicates(
#     subset=['year', 'month', 'day'],
#     keep='first'   # 첫 번째 남기고 나머지 삭제
# )
#
# weather_df['year'].value_counts()

# %%
# weather_df.to_csv("data/weather_raw.csv", index=False)
